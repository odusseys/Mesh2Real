# %%
# %load_ext autoreload
# %autoreload 2

from mesh2real.pipelines import Mesh2RealDiffuser
from mesh2real.utils import compute_edges
from mesh2real.utils import clear_cuda
from PIL import Image
from IPython.display import display

# %%
diffuser = Mesh2RealDiffuser.build()
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
clear_cuda()

img = Image.open("images/slot_machine_denoised .png")
edges = compute_edges(img)
display(diffuser("a photograph of a golden slot machine on a black background", edges=edges, controlnet_scale=0.8).resize((512, 512)))

# TODO
# IMG2IMG NO IP
# IMG2IMG IP
# TEXT2IMG IP
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# cross_attention_kwargs ['ip_adapter_masks'] are not expected by AttnProcessor2_0 and will be ignored.
# cross_attention_kwargs ['ip_adapter_masks'] are not expected by AttnProcessor2_0 and will be ignored.
# cross_attention_kwargs ['ip_adapter_masks'] are not expected by AttnProcessor2_0 and will be ignored.
# cross_attention_kwargs ['ip_adapter_masks'] are not expected by AttnProcessor2_0 and will be ignored.
# cross_attention_kwargs ['ip_adapter_masks'] are not expected by AttnProcessor2_0 and will be ignored.
# cross_attention_kwargs ['ip_adapter_masks'] are not expected by AttnProcessor2_0 and will be ignored.
# cross_attention_kwargs ['ip_adapter_masks'] are not expected by AttnProcessor2_0 and will be ignored.
# cross_attention_kwargs ['ip_adapter_masks'] are not expected by AttnProcessor2_0 and will be ignored.
# cross_attention_kwargs ['ip_adapter_masks'] are not expected by AttnProcessor2_0 and will be ignored.
# ...

# %%
diffuser.text2img_pipeline.to("cuda")
for k in diffuser.text2img_pipeline.components:
    if hasattr(diffuser.text2img_pipeline.components[k], "dtype"):
        print(k, diffuser.text2img_pipeline.components[k].dtype, diffuser.text2img_pipeline.components[k].device)
# Out:
# vae torch.float16 cuda:0
# text_encoder torch.float16 cuda:0
# text_encoder_2 torch.float16 cuda:0
# unet torch.float16 cuda:0
# controlnet torch.float16 cuda:0
# image_encoder torch.float16 cuda:0
