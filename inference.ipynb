# %%
# %load_ext autoreload
# %autoreload 2

from mesh2real.pipelines import Mesh2RealDiffuser
from mesh2real.utils import compute_edges
from mesh2real.utils import clear_cuda
from PIL import Image
from IPython.display import display

# %%
diffuser = Mesh2RealDiffuser.build()
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Using cache found in /home/zeus/.cache/torch/hub/mhamilton723_FeatUp_main
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/featup/featurizers/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/featup/featurizers/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
# ...

# %%
from mesh2real.mesh import load_mesh

mesh = load_mesh("slot_machine.obj")

# %%
from mesh2real.view_generation import ViewGenerator
view_generator = ViewGenerator()
# Out:
# Initializing rendering context, this may take a while
# Rendering context ready
# Loading pipeline components...:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
main_view, views = view_generator.generate_views(diffuser, mesh, "a photograph of a golden slot machine on a black background")
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# image and edges (1024, 1024) (1024, 1024)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /teamspace/studios/this_studio/inference.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell://vscode-01ht2gyt5ynf3247k2s7ahg8ev.studio.lightning.ai/teamspace/studios/this_studio/inference.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> main_view, views = view_generator.generate_views(diffuser, mesh, "a photograph of a golden slot machine on a black background")
#
# File ~/mesh2real/view_generation.py:102, in ViewGenerator.generate_views(self, diffusion_pipeline, mesh, prompt, negative_prompt, num_inference_steps)
#     100 self.to("cuda")
#     101 condition_edges, condition_depth, depth_grid, view_edges = prepare_zero123_inputs(mesh)
# ...

# %%
display(main_view)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
print(views)
for v in views:
    display(v.resize((256,256)))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>
